# %% [markdown]
# # 14.5 2012联邦选举委员会数据库

# %%
import pandas as pd 
import numpy as np 

fec = pd.read_csv("data/fec/P00000001-ALL.csv")
fec.info()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3098: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001731 entries, 0 to 1001730
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   cmte_id            1001731 non-null  object
#  1   cand_id            1001731 non-null  object
#  2   cand_nm            1001731 non-null  object
#  3   contbr_nm          1001731 non-null  object
#  4   contbr_city        1001712 non-null  object
#  5   contbr_st          1001727 non-null  object
#  6   contbr_zip         1001620 non-null  object
#  7   contbr_employer    988002 non-null   object
#  8   contbr_occupation  993301 non-null   object
# ...

# %%
fec.iloc[123456]
# Out:
# cmte_id                             C00431445
# cand_id                             P80003338
# cand_nm                         Obama, Barack
# contbr_nm                         ELLMAN, IRA
# contbr_city                             TEMPE
# contbr_st                                  AZ
# contbr_zip                          852816719
# contbr_employer      ARIZONA STATE UNIVERSITY
# contbr_occupation                   PROFESSOR
# contb_receipt_amt                        50.0
# contb_receipt_dt                    01-DEC-11
# receipt_desc                              NaN
# memo_cd                                   NaN
# memo_text                                 NaN
# form_tp                                 SA17A
# file_num                               772372
# Name: 123456, dtype: object

# %%
# 添加【党派】的数据列
unique_cands = fec.cand_nm.unique()
unique_cands
# Out:
# array(['Bachmann, Michelle', 'Romney, Mitt', 'Obama, Barack',
#        "Roemer, Charles E. 'Buddy' III", 'Pawlenty, Timothy',
#        'Johnson, Gary Earl', 'Paul, Ron', 'Santorum, Rick',
#        'Cain, Herman', 'Gingrich, Newt', 'McCotter, Thaddeus G',
#        'Huntsman, Jon', 'Perry, Rick'], dtype=object)

# %%
# 将候选人信息与党派进行联合
parties = {
    "Bachmann, Michelle":"共和党",
    'Cain, Herman': '共和党',
    'Gingrich, Newt': '共和党',
    'Huntsman, Jon': '共和党',
    'Johnson, Gary Earl': '共和党',
    'McCotter, Thaddeus G': '共和党',
    'Obama, Barack': '民主党',
    'Paul, Ron': '共和党',
    'Pawlenty, Timothy': '共和党',
    'Perry, Rick': '共和党',
    "Roemer, Charles E. 'Buddy' III": '共和党',
    'Romney, Mitt': '共和党',
    'Santorum, Rick': '共和党'
}

# %%
# 映射党派到候选人信息
print(fec.cand_nm[123456:123461])
print(fec.cand_nm[123456:123461].map(parties))
# Out:
# 123456    Obama, Barack
# 123457    Obama, Barack
# 123458    Obama, Barack
# 123459    Obama, Barack
# 123460    Obama, Barack
# Name: cand_nm, dtype: object
# 123456    民主党
# 123457    民主党
# 123458    民主党
# 123459    民主党
# 123460    民主党
# Name: cand_nm, dtype: object

# %%
fec['党派'] = fec.cand_nm.map(parties)
fec["党派"].value_counts()
# Out:
# 民主党    593746
# 共和党    407985
# Name: 党派, dtype: int64

# %%
# 候选宣传的支出费用
(fec.contb_receipt_amt > 0 ).value_counts()
# Out:
# True     991475
# False     10256
# Name: contb_receipt_amt, dtype: int64

# %%
fec = fec[fec.contb_receipt_amt > 0 ]
fec
# Out:
#            cmte_id    cand_id             cand_nm               contbr_nm  \
# 0        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2        C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3        C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4        C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...            ...        ...                 ...                     ...
# 1001726  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
# 1001727  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 1001728  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 1001729  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 1001730  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
#
#                 contbr_city contbr_st   contbr_zip  \
# ...

# %%
# 查看只包含obama和romney的数据
fec_mrbo = fec[fec.cand_nm.isin(['Obama, Barack','Romney, Mitt'])]
fec_mrbo
# Out:
#           cmte_id    cand_id        cand_nm           contbr_nm contbr_city  \
# 411     C00431171  P80003353   Romney, Mitt  ELDERBAUM, WILLIAM         DPO
# 412     C00431171  P80003353   Romney, Mitt  ELDERBAUM, WILLIAM         DPO
# 413     C00431171  P80003353   Romney, Mitt    CARLSEN, RICHARD         APO
# 414     C00431171  P80003353   Romney, Mitt      DELUCA, PIERRE         APO
# 415     C00431171  P80003353   Romney, Mitt    SARGENT, MICHAEL         APO
# ...           ...        ...            ...                 ...         ...
# 701381  C00431445  P80003338  Obama, Barack      MOUNTS, ROBERT         APO
# 701382  C00431445  P80003338  Obama, Barack     TAITANO, TYRONE     HAGATNA
# 701383  C00431445  P80003338  Obama, Barack      TUCKER, PAMELA         APO
# 701384  C00431445  P80003338  Obama, Barack      MOUNTS, ROBERT         APO
# 701385  C00431445  P80003338  Obama, Barack         NEAL, AMBER         APO
#
# ...

# %% [markdown]
# * 根据职业和雇主统计赞助信息
# 1. 基于职业的赞助信息统计是另一种经常被研究的统计任务。例如，律师们更倾向于资助民主党，而
# 企业主则更倾向于资助共和党。你可以不相信我，自己看那些数据就知道了。首先，根据职业计算
# 出资总额，这很简单:

# %%
fec.contbr_occupation.value_counts()[:10]
# Out:
# RETIRED                                   233990
# INFORMATION REQUESTED                      35107
# ATTORNEY                                   34286
# HOMEMAKER                                  29931
# PHYSICIAN                                  23432
# INFORMATION REQUESTED PER BEST EFFORTS     21138
# ENGINEER                                   14334
# TEACHER                                    13990
# CONSULTANT                                 13273
# PROFESSOR                                  12555
# Name: contbr_occupation, dtype: int64

# %%
occ_mapping = {
    "INFORMATION REQUESTED PER BEST EFFORTS":"不提供",
    "INFORMATION REQUESTED":"不提供",
    "INFORMATION REQUESTED(BEST EFFORTS)":"不提供",
    "C.E.0":"CEO"
    }

# %%
# 如果以上的映射就返回x
f = lambda x:occ_mapping.get(x,x)
fec.contbr_occupation = fec.contbr_occupation.map(f)
fec
# Out:
#            cmte_id    cand_id             cand_nm               contbr_nm  \
# 0        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2        C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3        C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4        C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...            ...        ...                 ...                     ...
# 1001726  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
# 1001727  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 1001728  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 1001729  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 1001730  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
#
#                 contbr_city contbr_st   contbr_zip  \
# ...

# %%
emp_mapping = {
    "INFORMATION REQUESTED PER BEST EFFORTS ":"不提供",
    "INFORMATION REQUESTED":"不提供",
    "INFORMATION REQUESTED PER BEST EFFORTS":"不提供",
    "SELF":"自由职业",
    "SELF EMPLOYED":"自由职业"
}
f = lambda x:emp_mapping.get(x,x)
fec.contbr_employer = fec.contbr_employer.map(f)
fec
# Out:
#            cmte_id    cand_id             cand_nm               contbr_nm  \
# 0        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2        C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3        C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4        C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...            ...        ...                 ...                     ...
# 1001726  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
# 1001727  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 1001728  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 1001729  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 1001730  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
#
#                 contbr_city contbr_st   contbr_zip  \
# ...

# %%
# 过滤总出资额不超过200万美元的数据
by_occupation  = fec.pivot_table(
    values ="contb_receipt_amt",
    index="contbr_occupation",
    columns = "党派",
    aggfunc = "sum"    
)

# %%
over_2mm = by_occupation[by_occupation.sum(1) > 2000000]
over_2mm
# Out:
# 党派                          共和党          民主党
# contbr_occupation
# ATTORNEY           7.477194e+06  11141982.97
# C.E.O.             2.592983e+06      1690.00
# CEO                1.618057e+06   2073284.79
# CONSULTANT         2.544725e+06   2459912.71
# ENGINEER           1.818374e+06    951525.55
# EXECUTIVE          4.138850e+06   1355161.05
# HOMEMAKER          1.363428e+07   4248875.80
# INVESTOR           2.431769e+06    884133.00
# LAWYER             3.912243e+05   3160478.87
# MANAGER            1.444532e+06    762883.22
# OWNER              2.408287e+06   1001567.36
# PHYSICIAN          3.594320e+06   3735124.94
# PRESIDENT          4.720924e+06   1878509.95
# PROFESSOR          2.967027e+05   2165071.08
# REAL ESTATE        1.625902e+06    528902.09
# RETIRED            2.356124e+07  25305116.38
# SELF-EMPLOYED      1.640253e+06    672393.40
# 不提供                2.056547e+07   4866973.96

# %%
import matplotlib.pyplot as plt 
'''-----plt：中文------'''
import matplotlib
print([f for f in matplotlib.font_manager.fontManager.ttflist if 'Heiti' in f.name])
matplotlib.rcParams['font.family'] = ['Heiti TC']

over_2mm.plot(kind="barh")
# Out:
# [<Font 'Heiti TC' (STHeiti Light.ttc) normal normal 300 normal>, <Font 'Heiti TC' (STHeiti Medium.ttc) normal normal 400 normal>]
# <AxesSubplot:ylabel='contbr_occupation'>

# %%
def get_top_amounts(group,key,n=5):
    totals = group.groupby(key)["contb_receipt_amt"].sum()
    return totals.nlargest(n)

# %%
# 职业与雇主进行聚合
grouped = fec_mrbo.groupby("cand_nm")
grouped.apply(get_top_amounts,"contbr_occupation",n= 7)
# Out:
# cand_nm        contbr_occupation
# Obama, Barack  RETIRED                                   25305116.38
#                ATTORNEY                                  11141982.97
#                INFORMATION REQUESTED                      4866973.96
#                HOMEMAKER                                  4248875.80
#                PHYSICIAN                                  3735124.94
#                LAWYER                                     3160478.87
#                CONSULTANT                                 2459912.71
# Romney, Mitt   RETIRED                                   11508473.59
#                INFORMATION REQUESTED PER BEST EFFORTS    11396894.84
#                HOMEMAKER                                  8147446.22
#                ATTORNEY                                   5364718.82
#                PRESIDENT                                  2491244.89
#                EXECUTIVE                                  2300947.03
# ...

# %%
grouped.apply(get_top_amounts, 'contbr_employer', n=10)
# Out:
# cand_nm        contbr_employer
# Obama, Barack  RETIRED                                   22694358.85
#                SELF-EMPLOYED                             17080985.96
#                NOT EMPLOYED                               8586308.70
#                INFORMATION REQUESTED                      5053480.37
#                HOMEMAKER                                  2605408.54
#                SELF                                       1076531.20
#                SELF EMPLOYED                               469290.00
#                STUDENT                                     318831.45
#                VOLUNTEER                                   257104.00
#                MICROSOFT                                   215585.36
# Romney, Mitt   INFORMATION REQUESTED PER BEST EFFORTS    12059527.24
#                RETIRED                                   11506225.71
#                HOMEMAKER                                  8147196.22
# ...

# %% [markdown]
# * 对出资额分组

# %%
bins = np.array([0, 1, 10, 100, 1000, 10000,100000, 1000000, 10000000])

# %%
labels = pd.cut(fec_mrbo.contb_receipt_amt,bins)
labels
# Out:
# 411         (10, 100]
# 412       (100, 1000]
# 413       (100, 1000]
# 414         (10, 100]
# 415         (10, 100]
#              ...
# 701381      (10, 100]
# 701382    (100, 1000]
# 701383        (1, 10]
# 701384      (10, 100]
# 701385    (100, 1000]
# Name: contb_receipt_amt, Length: 694282, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 10] < (10, 100] < (100, 1000] < (1000, 10000] < (10000, 100000] < (100000, 1000000] < (1000000, 10000000]]

# %%
# 根据候选人的姓名以及面元标签对两个候选人进行分组,以得到一个柱状图
grouped = fec_mrbo.groupby(["cand_nm",labels])
grouped.size().unstack(0)
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                         493            77
# (1, 10]                      40070          3681
# (10, 100]                   372280         31853
# (100, 1000]                 153991         43357
# (1000, 10000]                22284         26186
# (10000, 100000]                  2             1
# (100000, 1000000]                3             0
# (1000000, 10000000]              4             0

# %%
bucket_sums = grouped.contb_receipt_amt.sum().unstack(0)
normed_sums = bucket_sums.div(bucket_sums.sum(axis=1),axis=0)
normed_sums
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                    0.805182      0.194818
# (1, 10]                   0.918767      0.081233
# (10, 100]                 0.910769      0.089231
# (100, 1000]               0.710176      0.289824
# (1000, 10000]             0.447326      0.552674
# (10000, 100000]           0.823120      0.176880
# (100000, 1000000]         1.000000      0.000000
# (1000000, 10000000]       1.000000      0.000000

# %%
normed_sums[:-2].plot(kind="barh")
plt.title("两个候选人的赞助额度比例")
# Out:
# Text(0.5, 1.0, '两个候选人的赞助额度比例')

# %% [markdown]
# * 根据州统计赞助信息

# %%
grouped =fec_mrbo.groupby(["cand_nm","contbr_st"])

# %%
totals = grouped.contb_receipt_amt.sum().unstack(0).fillna(0)
totals = totals[totals.sum(1) > 100000]
totals[:10]
# Out:
# cand_nm    Obama, Barack  Romney, Mitt
# contbr_st
# AK             281840.15      86204.24
# AL             543123.48     527303.51
# AR             359247.28     105556.00
# AZ            1506476.98    1888436.23
# CA           23824984.24   11237636.60
# CO            2132429.49    1506714.12
# CT            2068291.26    3499475.45
# DC            4373538.80    1025137.50
# DE             336669.14      82712.00
# FL            7318178.58    8338458.81

# %%
percent = totals.div(totals.sum(1),axis=0)
percent[:10]
# Out:
# cand_nm    Obama, Barack  Romney, Mitt
# contbr_st
# AK              0.765778      0.234222
# AL              0.507390      0.492610
# AR              0.772902      0.227098
# AZ              0.443745      0.556255
# CA              0.679498      0.320502
# CO              0.585970      0.414030
# CT              0.371476      0.628524
# DC              0.810113      0.189887
# DE              0.802776      0.197224
# FL              0.467417      0.532583
